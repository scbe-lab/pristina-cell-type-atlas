# %%
import numpy as np
import pandas as pd
import scanpy as sc

# %%
pd.set_option('display.max_colwidth', None)

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sc.settings.verbosity = 4
sc.logging.print_header()
sc.settings.set_figure_params(dpi=300, facecolor='white', format = 'pdf', vector_friendly = True)

# %%
figure = "Figure_2"

# %%
sc.settings.figdir = './'+figure

# %%
umap_cmap = sns.blend_palette(['lightgrey', 'xkcd:medium blue'], as_cmap = True)

# %% [markdown]
# # Functions for diamond blast querying

# %%
def check_for_species(df, species):
    if df[4].str.contains(species).any():
        contained = df[df[4].str.contains(species)].sort_values(3)
        return contained.iloc[0, 4]
    else:
        return None

# %%
def contains_words (hit_string, li):
    ret = False
    for word in li:
        if word.lower() in hit_string:
            ret = True
    return ret

# %%
def get_informative (df, li):
    if len(df.index) == 0:
        return "not in Diamond"
    else:
        found = False
        i = 0
        while found == False and i in range(len(df.index)):
            se = df.iloc[i, 4].lower()
            if contains_words(se, li) == False:
                found = True
                return df.iloc[i, 4]
            i +=1  
        if found == False:
            return "no informative hits: "+df.iloc[0, 4]

# %%
def get_best_hit (transcript, species, li):
    search = diamond[diamond[0] == transcript]
    if check_for_species(search, species) is not None:
        return check_for_species(search, species)
    else:
        return get_informative (search, li)

# %%
list_of_words = ['hypothetical', 'uncharacterized', 'unnamed', 'Dimorphilus']

# %%
preferred_species = 'Platynereis'

# %%
diamond = pd.read_csv('../../diamond_pristina.tsv', sep='\t', header = None)

# %% [markdown]
# # Eggnog annotation

# %%
annot = pd.read_csv('../../annot.tsv', sep='\t', index_col = "query")

# %% [markdown]
# # Input file

# %%
adata = sc.read_h5ad('../../pristina_atlas_coloured_subcl.h5ad')

# %%
adata

# %%
adata.var

# %%
clusteringlayer = 'leiden_1.5'

# %%
list(adata.uns)

# %%
tr = 'PrileiEVm008309t1'
sc.pl.umap(adata, color= tr, color_map = umap_cmap, frameon = False,
           save = '_feature_'+tr+'.pdf')

# %%
get_best_hit (tr, preferred_species, list_of_words)

# %%
if tr in annot.index:
    print(annot.loc[tr])

# %%
tr = 'PrileiEVm000558t1'
sc.pl.umap(adata, color= tr, color_map = umap_cmap, frameon = False,
           save = '_feature_'+tr+'.pdf')

# %%
get_best_hit (tr, preferred_species, list_of_words)

# %%
if tr in annot.index:
    print(annot.loc[tr])

# %%
tr = 'PrileiEVm000300t1'
sc.pl.umap(adata, color= tr, color_map = umap_cmap, frameon = False,
           save = '_feature_'+tr+'.pdf')

# %%
get_best_hit (tr, preferred_species, list_of_words)

# %%
if tr in annot.index:
    print(annot.loc[tr])

# %%
tr = 'PrileiEVm026965t1'
sc.pl.umap(adata, color= tr, color_map = umap_cmap, frameon = False,
           save = '_feature_'+tr+'.pdf')

# %%
get_best_hit (tr, preferred_species, list_of_words)

# %%
if tr in annot.index:
    print(annot.loc[tr])

# %%
tr = 'PrileiEVm019805t1'
sc.pl.umap(adata, color= tr, color_map = umap_cmap, frameon = False,
           save = '_feature_'+tr+'.pdf')

# %%
get_best_hit (tr, preferred_species, list_of_words)

# %%
if tr in annot.index:
    print(annot.loc[tr])

# %%
tr = 'PrileiEVm005677t1'
sc.pl.umap(adata, color= tr, color_map = umap_cmap, frameon = False,
           save = '_feature_'+tr+'.pdf')

# %%
get_best_hit (tr, preferred_species, list_of_words)

# %%
if tr in annot.index:
    print(annot.loc[tr])

# %%
tr = 'PrileiEVm016330t1'
sc.pl.umap(adata, color= tr, color_map = umap_cmap, frameon = False,
           save = '_feature_'+tr+'.pdf')

# %%
get_best_hit (tr, preferred_species, list_of_words)

# %%
if tr in annot.index:
    print(annot.loc[tr])

# %%
tr = 'PrileiEVm017310t1'
sc.pl.umap(adata, color= tr, color_map = umap_cmap, frameon = False,
           save = '_feature_'+tr+'.pdf')

# %%
get_best_hit (tr, preferred_species, list_of_words)

# %%
if tr in annot.index:
    print(annot.loc[tr])

# %%
tr = 'PrileiEVm008813t1'
sc.pl.umap(adata, color= tr, color_map = umap_cmap, frameon = False,
           save = '_feature_'+tr+'.pdf')

# %%
get_best_hit (tr, preferred_species, list_of_words)

# %%
if tr in annot.index:
    print(annot.loc[tr])

# %%
tr = 'PrileiEVm010941t1'
sc.pl.umap(adata, color= tr, color_map = umap_cmap, frameon = False,
           save = '_feature_'+tr+'.pdf')

# %%
get_best_hit (tr, preferred_species, list_of_words)

# %%
if tr in annot.index:
    print(annot.loc[tr])

# %%
tr = 'PrileiEVm021761t1'
sc.pl.umap(adata, color= tr, color_map = umap_cmap, frameon = False,
           save = '_feature_'+tr+'.pdf')

# %%
get_best_hit (tr, preferred_species, list_of_words)

# %%
if tr in annot.index:
    print(annot.loc[tr])

# %%
gut_lum = adata.obs[adata.obs['broad_names'] == 'gut'][clusteringlayer].unique().to_list()

# %%
gut_lum

# %%
gut_lum.remove('16')

# %%
gut_lum

# %%
gut_lum.append(adata.obs[adata.obs['broad_names'] == 'lumbrokinase+ cells'][clusteringlayer].unique().to_list()[0])

# %%
gut_lum

# %%
 with plt.rc_context({'figure.figsize': (12, 12)}):
        sc.pl.umap(adata, color=clusteringlayer, groups = gut_lum,
            legend_loc='on data', na_color = 'lightgrey', na_in_legend = False,
            legend_fontsize = 10, legend_fontoutline = 3, size = 10,
            frameon=False, add_outline = False, save = '_'+figure+'_gut_lum.pdf')

# %%
e_m_n = []
for i in adata.obs[clusteringlayer].cat.categories:
    if (adata.obs.loc[adata.obs[clusteringlayer] == i, 'broad_names'][0] == 'epidermis') or (adata.obs.loc[adata.obs[clusteringlayer] == i, 'broad_names'][0] == 'muscle') or (adata.obs.loc[adata.obs[clusteringlayer] == i, 'broad_names'][0] == 'neurons'):
        e_m_n.append(i)

# %%
with plt.rc_context({'figure.figsize': (12, 12)}):
    sc.pl.umap(adata, color=clusteringlayer, groups = e_m_n,
        legend_loc= None, na_color = 'lightgrey', na_in_legend = False,
        size = 10,
        frameon=False, add_outline = False, save = '_'+figure+'_epid_neur_mus.pdf')

# %%
gut_fluo_colors = {
    '14': '#DDDD05',
    '39': '#DDDD05',
    '26': '#FF9D00',
    '31': '#00DEDE',
    '28': '#F93E82',
    '19': '#31A7FF',
    '9': '#5E51E1', 
    '15': '#FF00F9',
    }

# %%
gut_fluo_palette = []
for i in adata.obs['leiden_1.5'].cat.categories:
    if i in gut_fluo_colors:
        gut_fluo_palette.append(gut_fluo_colors[i])
    else:
        gut_fluo_palette.append('grey')

# %%
gut_fluo_palette

# %%
with plt.rc_context({'figure.figsize': (12, 12)}):
    sc.pl.umap(adata, color=clusteringlayer, groups = gut_lum,
        legend_loc= None, na_color = 'lightgrey', na_in_legend = False,
        size = 10, palette = gut_fluo_palette,
        frameon=False, add_outline = False, save = '_'+figure+'_gut_lum_fluo.pdf')
